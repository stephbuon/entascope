# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


def plot_single_source(measurements, filter_by, ts, source):
    
    measurements = measurements[:30].copy()

    measurements.sort_values(by = ['proportion'], inplace = True, ascending = True)

    if filter_by == 'PERSON':
        if source == 'NPR':
            politicians = ['biden', 'kathy hochul', 'hochul', 'bill de blasio', 'gavin newsom', 'trump', 'donald trump', 'newsom']
            infectious_diseases_expert = ['michael ryan', 'mathai mammen', 'michael osterholm', 'mikael dolsten', 'kilgore', 'pollack', 'van kerkhove', 'rochelle walensky', 'Anthony fauci', 'francis collins', 'collins', 'fauci', 'osterholm', 'chu', 'tedros', 'maria van kerkhove', 'walensky', 'rick pollack', 'tedros adhanom ghebreyesus']
            other_people = ['mark ghaly', 'allie', 'lloyd austin', 'kirby', 'alejandro brown']

        if source == 'FOX':
            politicians = ['biden', 'greg abbott', 'harris', 'desantis', 'newsom', 'ron desantis', 'cuomo', 'bill de blasio', 'psaki', 'kate brown', 'brandon', 'kamala harris', 'joe biden', 'trump', 'jen psaki', 'de blasio', 'donald trump', 'kathy hochul', 'gavin newsom', 'abbott', 'hochul', 'andrew cuomo']
            infectious_diseases_expert = ['fauci', 'anthony fauci', 'rochelle walensky']
            other_people = ['horak', 'twitter', 'brown', 'Alejandro Mayorkas', 'Mayorkas', 'powell', 'marc siegel']
    
        measurements['color'] = 'red'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in politicians]), 'color'] = '#404788FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in infectious_diseases_expert]), 'color'] = '#B8DE29FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in other_people]), 'color'] = '#20A387FF'

        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in politicians]), 'type'] = 'Politician'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in infectious_diseases_expert]), 'type'] = 'Infectious Diseases Expert'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in other_people]), 'type'] = 'Other'

        # politician_legend = mpatches.Patch(color = '#404788FF', label = 'Politician')
        # infectious_diseases_expert = mpatches.Patch(color = '#B8DE29FF', label = 'Infectious Diseases Expert')
        # other_people = mpatches.Patch(color = '#20A387FF', label = 'Other')

        # plt.legend(handles=[politician_legend, infectious_diseases_expert, other_people])

    if filter_by == 'ORG':
        if source == 'FOX':

            political_orgs = ['capitol hill', 'White House', 'Republican', 'Democrats', 'Republicans', 'Democratic', 'Senate', 'House', 'Democrat', 'Congress', 'GOP']
            health_orgs = ['CDC', 'FDA', 'Centers For Disease Control and Prevention', 'Pfizer', 'Moderna', 'HHS', 'Abbot', 'Brown', 'NIH', 'Food And Drug Administration']
            enforcement = ['Occupational Safety And Health Administration', 'Navy', 'CBP', 'Homeland Security', 'Air Force', 'Osha', 'Pentagon']
            other = ['Supreme Court', 'GE', 'State', 'fdny', 'university of alabama']

        if source == 'NPR':

            political_orgs = ['white house', 'republican', 'senate']
            health_orgs = ['cdc', 'Johns Hopkins University', 'johnson & johnson covid-19', 'johnson & johnson', 'merck', 'nomi health', 'national institutes of health', 'food and drug administration', 'pfizer', 'centers for disease control and prevention', 'moderna', 'fda', 'who', 'world health organization', 'j&j', 'nih']
            enforcement = ['air force', 'army', 'pentagon']
            other = ['los angeles county', 'nfl', 'nhl', 'lufthansa', 'las vegas raiders', 'united airlines', 'cornell', 'cornell university', 'carnival', 'united']

        measurements['color'] = 'red'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in political_orgs]), 'color'] = '#481567FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in health_orgs]), 'color'] = '#39568CFF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in other]), 'color'] = '#B8DE29FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in enforcement]), 'color'] = '#3CBB75FF'

        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in political_orgs]), 'type'] = 'Political Org'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in health_orgs]), 'type'] = 'Health Org'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in other]), 'type'] = 'Other'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in enforcement]), 'type'] = 'Enforcement'

        # political_orgs = mpatches.Patch(color = '#481567FF', label = 'Political Org')
        # health_orgs = mpatches.Patch(color = '#39568CFF', label = 'Health Org')
        # enforcement = mpatches.Patch(color = '#3CBB75FF', label = 'Enforcement')
        # other = mpatches.Patch(color = '#B8DE29FF', label = 'Other')

        # plt.legend(handles=[political_orgs, health_orgs, enforcement, other])

    if filter_by == 'EVENT':
        if source == 'FOX':
            
            pandemic = ['Covid-19 Vaccine Dose', 'covid-19 tests', 'covid-19', 'covid-19 vaccination', 'omicron', 'delta', 'coronavirus', 'covid', 'vaccine', 'covid-19 vaccine', 'access to free covid tests', 'vaccines', 'Covid-19 Pandemic', 'somewhere past the pandemic', 'Mask', 'Anti-Covid']
            enforcement = ['signs bills limiting vaccine mandates in brandon', 'mask mandate', 'Covid-19 Vaccine Mandated', 'announce vaccine mandate', 'covid-19 vaccine mandate', 'vaccine mandate', 'Mandate', 'Vax Mandate Amid Southwest', 'Abbott school mask rules in line with many foreign', 'Governor Mandate', 'NYC Workers Vaccine Mandate Protest Shuts Down Brooklyn Bridge Traffic into Manhattan', 'California First State To Require Covid Vaccinations for K-12 Students']
            national_event = ['twitter monday', 'annual national peace officer memorial service', 'Valor Awards']
            international_event = ['winter olympics', 'christmas eve', 'world war ii', 'New Year', 'New Year Eve'] 

        if source == 'NPR':

            pandemic = ['Year Before Covid', 'Covid-19 Vaccine', 'b.1.1.529', 'covid', 'mask', 'vaccine', 'delta', 'omicron', 'covid-19', 'weekly coronavirus questions']
            enforcement = []
            national_event = ['independence day', 'operation warp speed', 'black friday']
            international_event = ['tokyo summer olympics', 'second world war', 'winter olympic games', 'Summer Olympics', 'Great Recession', 'Olympic Games', 'vaccinate 10%', 'breakthrough covid-19', 'new year', 'winter olympics', 'tts', 'christmas eve', 'thanksgiving', 'olympics', 'new year eve', 'tokyo olympics', 'world war ii', 'world aids day', 'civil war', 'winter games']

        measurements['color'] = 'red'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in pandemic]), 'color'] = '#481567FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in enforcement]), 'color'] = '#39568CFF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in national_event]), 'color'] = '#B8DE29FF'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in international_event]), 'color'] = '#3CBB75FF'

        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in pandemic]), 'type'] = 'COVID'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in enforcement]), 'type'] = 'Enforcement'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in national_event]), 'type'] = 'National Event'
        measurements.loc[measurements['entity_text'].str.lower().isin([x.lower() for x in international_event]), 'type'] = 'International Event'

        # covid_and_covid_products = mpatches.Patch(color = '#481567FF', label = 'COVID/COVID Products')
        # enforcement_ = mpatches.Patch(color = '#39568CFF', label = 'Enforcement')
        # national_event_ = mpatches.Patch(color = '#B8DE29FF', label = 'National Event')
        # international_event_ = mpatches.Patch(color = '#3CBB75FF', label = 'International Event')

        # plt.legend(handles=[covid_and_covid_products, enforcement_, national_event_, international_event_])

    measurements.to_csv('/home/stephbuon/projects/entascope/results/12-27-2021/' + source + '_' + filter_by + '_plot_data.csv')

    plt.barh(measurements['entity_text'], measurements['proportion'], color = measurements['color'])

    plt.ylabel(filter_by + ' Name')

    plt.margins(y=.005)

    plt.title('Highest proportion of event ' + filter_by + ' tagged enitites in ' + source + ' News Articles about Covid-19' )
    #plt.suptitle('Proportion is measured against the total number of ' + filter_by + ' tagged entities')

    plt.suptitle('Proportion is measured against the total number of ' + filter_by + ' tagged entities', 
    x=0.5, y=.0099, horizontalalignment='center', verticalalignment='bottom', fontsize = 10)

    plt.rcParams["figure.figsize"] = [6,8]

    plt.savefig('/home/stephbuon/projects/entascope/results/' + ts + '/' + source + '_' + filter_by + '.pdf')
    plt.show()
    plt.close()

# %%
ts = '12-27-2021'

ss = 'FOX'
ff = ['PERSON', 'EVENT', 'ORG']

for f in ff:
    measured_data = pd.read_csv('/home/stephbuon/projects/entascope/results/12-27-2021/' + ss + '_' + f + '.csv')
    source = measured_data['source'].iloc[0]
    filter_by = measured_data['entity_label'].iloc[0]
    plot_single_source(measured_data, filter_by=filter_by, ts=ts, source=source)

# %%
#cummulative percentage of what the top 20 cover 
# .0001 + .0001

# I am covering this part of the data set
